# %% [markdown]
# <a href="https://colab.research.google.com/github/tozakichen/kkk/blob/main/_11_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業繳交資訊
# #### 請同學將作業下載成「第 n 組作業.ipynb」後上傳至[python作業繳交區表單](https://forms.gle/H2XP3vj8qhjN3rhX9)
# #### 每組只需上傳1份
# #### 作業可以討論，但請勿抄襲（借別人抄跟抄別人的都連坐罰）

# %% [markdown]
# # 分組資訊
# ## 組別：11
# ## 主題：Europe
# ## 組員名單（學號/姓名）：
# 1.412351225 梁景翔
#
# 2.412351548 錢積霆
#
# 3.412351110 王研
#
# 4.412351134 陳梓觀
#
# 5.412351122 何深山

# %% [markdown]
# # 資料集說明
# 資料集來源：[ESG & Financial Performance Dataset](https://www.kaggle.com/datasets/shriyashjagtap/esg-and-financial-performance-dataset)
#
# 欄位名稱及資料型態
# 1. 公司代碼(CompanyID)：Object
# 2. 產業(Industry)：Object
# 3. 所在地區(Region)：Object
# 4. 資料年份(Year)：int
# 5. 年收入_百萬美元(Revenue)：float
# 6. 邊際利潤(ProfitMargin)：float
# 7. 市值_百萬美元(MarketCap)：float
# 8. 年收成長率(GrowthRate)：float
# 9. ESG總得分(ESG_Overall)：float
# 10. 永續環境(ESG_Environmental)：float
# 11. 社會責任(ESG_Social)：float
# 12. 公司治理(ESG_Governance)：float
# 13. 二氧化碳排放量(CarbonEmissions)：float
# 14. 用水量(WaterUsage)：float
# 15. 能源消費(EnergyConsumption)：float

# %% [markdown]
# # 第一題、匯入資料集(17% = 4% + 4% + 9%)
# #### (1)利用input指令讓使用者自行輸入已共享google試算表的連結代碼（變數名稱為ID）以取得後續資料
# #### (2)將抓取google試算表的下載網址定義成一個字串變數(Filename)
# #### (3)利用pandas中的read_excel分別讀入「Financial_Data」、「ESG_Score」、「OTHERS」三張頁籤的資料（工作表名稱即為資料集的變數名稱）

# %%
import pandas as pd
ID = input("請輸入已共享google試算表的連結代碼：")
Filename = f'https://docs.google.com/spreadsheets/d/{ID}/export?format=xlsx'
Financial_Data = pd.read_excel(Filename, sheet_name='Financial_Data')
ESG_Score = pd.read_excel(Filename, sheet_name='ESG_Score')
OTHERS = pd.read_excel(Filename, sheet_name='OTHERS')
# Out:
# 請輸入已共享google試算表的連結代碼：14Oa-3Nz1JXab7xo6E_VFXcJVYM2tvYHu

# %% [markdown]
# # 第二題、合併資料集（用pd.merge 或 pd.concat）(5%)
# #### 請將上面三個資料集（Financial_Data、ESG_Score、OTHERS）合併成一個資料集(Company_ESG)

# %%
Company_ESG = pd.merge(Financial_Data, ESG_Score, on=['CompanyID'])

Company_ESG = pd.merge(Company_ESG, OTHERS, on=['CompanyID'])

# %%
Company_ESG
# Out:
#      CompanyID        Industry         Region  Year  Revenue  ProfitMargin  \
# 0            1          Retail  Latin America  2025    734.5           5.0
# 1            2          Retail           Asia  2025   4371.5          -2.4
# 2            3  Transportation  Latin America  2025    479.8          11.6
# 3            4      Technology         Africa  2025   7675.6          22.9
# 4            5         Finance    Middle East  2025   3162.1          22.4
# ..         ...             ...            ...   ...      ...           ...
# 995        996      Healthcare         Europe  2025   5503.9          20.3
# 996        997       Utilities         Africa  2025    642.9          10.2
# 997        998      Healthcare        Oceania  2025   2042.3          29.8
# 998        999         Finance           Asia  2025   5700.3          21.6
# 999       1000  Consumer Goods  Latin America  2025   3173.5          17.5
#
#      MarketCap  GrowthRate  ESG_Overall_x  ESG_Environmental_x  ...  \
# 0        628.8         6.9           59.2                 70.7  ...
# 1      20376.3        14.4           66.3                 65.8  ...
# 2       1020.7         9.5           34.3                 24.4  ...
# 3      42400.4        17.1           64.1                100.0  ...
# 4       6674.6        -3.7           48.0                 82.1  ...
# ..         ...         ...            ...                  ...  ...
# 995    25775.5        -7.0           60.4                 91.3  ...
# 996      818.5         1.3           66.7                 49.5  ...
# 997    12788.3        11.1           65.6                100.0  ...
# 998    19402.0         4.3           53.1                100.0  ...
# 999     5666.1        -0.3           51.8                 74.5  ...
#
#      CarbonEmissions_x  WaterUsage_x  EnergyConsumption_x  ESG_Overall_y  \
# 0              51805.8       25902.9             103611.7           59.2
# 1             323282.0      161641.0             646564.1           66.3
# 2             296242.0       49373.7             987473.3           34.3
# 3             191891.1      115134.7             383782.3           64.1
# 4              39561.3       19780.6              98903.2           48.0
# ..                 ...           ...                  ...            ...
# 995           308688.0      308688.0             617376.0           60.4
# 996           439038.9      274399.3            4390388.8           66.7
# 997           102112.6      102112.6             204225.2           65.6
# 998            57003.4       28501.7             142508.6           53.1
# 999           430741.6      538427.0            2153707.9           51.8
#
#      ESG_Environmental_y  ESG_Social_y  ESG_Governance_y  CarbonEmissions_y  \
# 0                   70.7          29.1              78.0            51805.8
# 1                   65.8          62.8              70.3           323282.0
# 2                   24.4          43.7              34.9           296242.0
# 3                  100.0          65.4              27.0           191891.1
# 4                   82.1          18.7              43.3            39561.3
# ..                   ...           ...               ...                ...
# 995                 91.3          32.9              56.9           308688.0
# 996                 49.5          91.4              59.2           439038.9
# 997                100.0          31.7              65.2           102112.6
# 998                100.0          16.2              43.1            57003.4
# 999                 74.5          39.7              41.4           430741.6
#
#      WaterUsage_y  EnergyConsumption_y
# 0         25902.9             103611.7
# 1        161641.0             646564.1
# 2         49373.7             987473.3
# 3        115134.7             383782.3
# 4         19780.6              98903.2
# ..            ...                  ...
# 995      308688.0             617376.0
# 996      274399.3            4390388.8
# 997      102112.6             204225.2
# 998       28501.7             142508.6
# 999      538427.0            2153707.9
#
# [1000 rows x 22 columns]

# %% [markdown]
# # 第三題、確認資料型態(10%)
# #### 請用info()確認「資料集Company_ESG」的資料型態是否符合上述資料集說明中的定義，如果不符合，請轉成適合的型別，再存回「資料集Company_ESG」中。

# %%
Company_ESG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CompanyID            1000 non-null   int64
#  1   Industry             1000 non-null   object
#  2   Region               1000 non-null   object
#  3   Year                 1000 non-null   int64
#  4   Revenue              1000 non-null   float64
#  5   ProfitMargin         1000 non-null   float64
#  6   MarketCap            1000 non-null   float64
#  7   GrowthRate           1000 non-null   float64
#  8   ESG_Overall_x        1000 non-null   float64
#  9   ESG_Environmental_x  1000 non-null   float64
#  10  ESG_Social_x         1000 non-null   float64
#  11  ESG_Governance_x     1000 non-null   float64
#  12  CarbonEmissions_x    1000 non-null   float64
#  13  WaterUsage_x         1000 non-null   float64
#  14  EnergyConsumption_x  1000 non-null   float64
#  15  ESG_Overall_y        1000 non-null   float64
#  16  ESG_Environmental_y  1000 non-null   float64
#  17  ESG_Social_y         1000 non-null   float64
#  18  ESG_Governance_y     1000 non-null   float64
#  19  CarbonEmissions_y    1000 non-null   float64
#  20  WaterUsage_y         1000 non-null   float64
#  21  EnergyConsumption_y  1000 non-null   float64
# dtypes: float64(18), int64(2), object(2)
# memory usage: 172.0+ KB

# %% [markdown]
# # 第四題、刪除特定資料(5%)
# #### 因此資料皆為2025年的資料，所以「資料集Company_ESG」中的year皆相同，無區別性，故請用drop()將此year刪除，並存回「資料集Company_ESG」的year中

# %%
Company_ESG = Company_ESG.drop('Year', axis=1)

# %% [markdown]
# # 第五題、欄位名稱變更及重新定義資料集索引(10%)
# #### (1)請用rename將「CompanyID」更名為「ID」，以及「CarbonEmissions」更名為「CO2排放量」，並存回「資料集Company_ESG」中
# #### (2)請用set_index將ID定義為「資料集Company_ESG」的索引

# %%
Company_ESG = Company_ESG.rename(columns={'CompanyID': 'ID', 'CarbonEmissions_x': 'CO2排放量'})
Company_ESG = Company_ESG.set_index('ID')

# %%
Company_ESG
# Out:
#             Industry         Region  Revenue  ProfitMargin  MarketCap  \
# ID
# 1             Retail  Latin America    734.5           5.0      628.8
# 2             Retail           Asia   4371.5          -2.4    20376.3
# 3     Transportation  Latin America    479.8          11.6     1020.7
# 4         Technology         Africa   7675.6          22.9    42400.4
# 5            Finance    Middle East   3162.1          22.4     6674.6
# ...              ...            ...      ...           ...        ...
# 996       Healthcare         Europe   5503.9          20.3    25775.5
# 997        Utilities         Africa    642.9          10.2      818.5
# 998       Healthcare        Oceania   2042.3          29.8    12788.3
# 999          Finance           Asia   5700.3          21.6    19402.0
# 1000  Consumer Goods  Latin America   3173.5          17.5     5666.1
#
#       GrowthRate  ESG_Overall_x  ESG_Environmental_x  ESG_Social_x  \
# ID
# 1            6.9           59.2                 70.7          29.1
# 2           14.4           66.3                 65.8          62.8
# 3            9.5           34.3                 24.4          43.7
# 4           17.1           64.1                100.0          65.4
# 5           -3.7           48.0                 82.1          18.7
# ...          ...            ...                  ...           ...
# 996         -7.0           60.4                 91.3          32.9
# 997          1.3           66.7                 49.5          91.4
# 998         11.1           65.6                100.0          31.7
# 999          4.3           53.1                100.0          16.2
# 1000        -0.3           51.8                 74.5          39.7
#
#       ESG_Governance_x    CO2排放量  WaterUsage_x  EnergyConsumption_x  \
# ID
# 1                 78.0   51805.8       25902.9             103611.7
# 2                 70.3  323282.0      161641.0             646564.1
# 3                 34.9  296242.0       49373.7             987473.3
# 4                 27.0  191891.1      115134.7             383782.3
# 5                 43.3   39561.3       19780.6              98903.2
# ...                ...       ...           ...                  ...
# 996               56.9  308688.0      308688.0             617376.0
# 997               59.2  439038.9      274399.3            4390388.8
# 998               65.2  102112.6      102112.6             204225.2
# 999               43.1   57003.4       28501.7             142508.6
# 1000              41.4  430741.6      538427.0            2153707.9
#
#       ESG_Overall_y  ESG_Environmental_y  ESG_Social_y  ESG_Governance_y  \
# ID
# 1              59.2                 70.7          29.1              78.0
# 2              66.3                 65.8          62.8              70.3
# 3              34.3                 24.4          43.7              34.9
# 4              64.1                100.0          65.4              27.0
# 5              48.0                 82.1          18.7              43.3
# ...             ...                  ...           ...               ...
# 996            60.4                 91.3          32.9              56.9
# 997            66.7                 49.5          91.4              59.2
# 998            65.6                100.0          31.7              65.2
# 999            53.1                100.0          16.2              43.1
# 1000           51.8                 74.5          39.7              41.4
#
#       CarbonEmissions_y  WaterUsage_y  EnergyConsumption_y
# ID
# 1               51805.8       25902.9             103611.7
# 2              323282.0      161641.0             646564.1
# 3              296242.0       49373.7             987473.3
# 4              191891.1      115134.7             383782.3
# 5               39561.3       19780.6              98903.2
# ...                 ...           ...                  ...
# 996            308688.0      308688.0             617376.0
# 997            439038.9      274399.3            4390388.8
# 998            102112.6      102112.6             204225.2
# 999             57003.4       28501.7             142508.6
# 1000           430741.6      538427.0            2153707.9
#
# [1000 rows x 20 columns]

# %% [markdown]
# # 第六題、資料排序(5%)
# #### 請將「資料集Company_ESG」的資料依ESG_Overall大小由大至小排序，並將排序結果回存至「資料集Company_ESG」中

# %%
Company_ESG = Company_ESG.sort_values(by='ESG_Overall_x', ascending=False)

# %% [markdown]
# # 第七題、重新定義變數涵意及新增變數(18% = 3% + 10% + 5%)
# #### (1)建立一個空的list變數(New_Group)
# #### (2)利用for迴圈及ifelse判斷式將「資料集Company_ESG」中的ESG_Overall重新定義成3組別：
# - 小於60分(不含60)
# - 60-80分(不含80)
# - 80分以上
#
# #### (3)在「資料集Company_ESG」中新增一個欄位為「ESG成績分組」。

# %%
New_Group = []
for score in Company_ESG['ESG_Overall_x']:
  if score < 60:
    New_Group.append('0~60')
  elif 60 <= score < 80:
    New_Group.append('60~80')
  else:
    New_Group.append('80<=')
Company_ESG['ESG成績分組'] = New_Group

# %%
Company_ESG
# Out:
#            Industry         Region  Revenue  ProfitMargin  MarketCap  \
# ID
# 478         Finance         Europe  11483.5           7.9    15330.3
# 870         Finance  Latin America  10588.4           2.0     2859.0
# 472      Healthcare         Europe   4953.8          14.2     9569.8
# 157  Consumer Goods         Europe   6055.5          23.8    21083.4
# 378      Technology        Oceania   2554.2          36.6    27445.4
# ..              ...            ...      ...           ...        ...
# 84   Consumer Goods    Middle East   4337.2           6.0     2769.7
# 141          Energy         Africa   7528.4          -7.7     8699.6
# 185  Transportation  Latin America    793.8          -5.4     3335.6
# 302          Energy  Latin America   2102.7          11.5     3913.4
# 311  Consumer Goods    Middle East   6459.0          11.4    12785.6
#
#      GrowthRate  ESG_Overall_x  ESG_Environmental_x  ESG_Social_x  \
# ID
# 478         0.5           98.0                100.0         100.0
# 870        10.0           96.0                100.0          93.3
# 472        14.4           95.6                 96.5          99.2
# 157        -1.0           95.4                 99.1         100.0
# 378         0.8           95.3                 91.3          98.8
# ..          ...            ...                  ...           ...
# 84         15.6           18.1                 38.5           3.1
# 141         3.5           17.8                 47.2           0.0
# 185         3.8           16.5                 12.6          14.1
# 302         2.0           16.1                 31.5          14.8
# 311        -4.5           14.3                 15.3          15.5
#
#      ESG_Governance_x  ...  WaterUsage_x  EnergyConsumption_x  ESG_Overall_y  \
# ID                     ...
# 478              94.0  ...       57417.6             287088.0           98.0
# 870              94.7  ...       52942.1             264710.3           96.0
# 472              91.3  ...      259802.9             519605.9           95.6
# 157              87.2  ...      766314.8            3065259.2           95.4
# 378              95.8  ...       42983.5             143278.2           95.3
# ..                ...  ...           ...                  ...            ...
# 84               12.8  ...     1009192.0            4036767.9           18.1
# 141               6.3  ...     1963236.4           65441212.7           17.8
# 185              22.7  ...       88235.1            1764702.6           16.5
# 302               1.8  ...      617650.2           20588340.1           16.1
# 311              11.9  ...     1764542.3            7058169.2           14.3
#
#      ESG_Environmental_y  ESG_Social_y  ESG_Governance_y  CarbonEmissions_y  \
# ID
# 478                100.0         100.0              94.0           114835.2
# 870                100.0          93.3              94.7           105884.1
# 472                 96.5          99.2              91.3           259802.9
# 157                 99.1         100.0              87.2           613051.8
# 378                 91.3          98.8              95.8            71639.1
# ..                   ...           ...               ...                ...
# 84                  38.5           3.1              12.8           807353.6
# 141                 47.2           0.0               6.3          6544121.3
# 185                 12.6          14.1              22.7           529410.8
# 302                 31.5          14.8               1.8          2058834.0
# 311                 15.3          15.5              11.9          1411633.8
#
#      WaterUsage_y  EnergyConsumption_y  ESG成績分組
# ID
# 478       57417.6             287088.0     80<=
# 870       52942.1             264710.3     80<=
# 472      259802.9             519605.9     80<=
# 157      766314.8            3065259.2     80<=
# 378       42983.5             143278.2     80<=
# ..            ...                  ...      ...
# 84      1009192.0            4036767.9     0~60
# 141     1963236.4           65441212.7     0~60
# 185       88235.1            1764702.6     0~60
# 302      617650.2           20588340.1     0~60
# 311     1764542.3            7058169.2     0~60
#
# [1000 rows x 21 columns]

# %% [markdown]
# # 第八題、資料篩選(loc)(10%)
# #### 依分組名單中的主題選取符合主題條件的列資料，以及須保留以下欄位，並另存成「資料集ESG_NumericData」：
# 1. ESG_Overall
# 2. ESG_Environmental
# 3. ESG_Social
# 4. ESG_Governance
# 5. CO2排放量
# 6. WaterUsage
# 7. EnergyConsumption

# %%
selected_columns = ['ESG_Overall_x', 'ESG_Environmental_x', 'ESG_Social_x', 'ESG_Governance_x', 'CO2排放量', 'WaterUsage_x', 'EnergyConsumption_x']
ESG_NumericData = Company_ESG.loc[:, selected_columns]
ESG_NumericData
# Out:
#      ESG_Overall_x  ESG_Environmental_x  ESG_Social_x  ESG_Governance_x  \
# ID
# 478           98.0                100.0         100.0              94.0
# 870           96.0                100.0          93.3              94.7
# 472           95.6                 96.5          99.2              91.3
# 157           95.4                 99.1         100.0              87.2
# 378           95.3                 91.3          98.8              95.8
# ..             ...                  ...           ...               ...
# 84            18.1                 38.5           3.1              12.8
# 141           17.8                 47.2           0.0               6.3
# 185           16.5                 12.6          14.1              22.7
# 302           16.1                 31.5          14.8               1.8
# 311           14.3                 15.3          15.5              11.9
#
#         CO2排放量  WaterUsage_x  EnergyConsumption_x
# ID
# 478   114835.2       57417.6             287088.0
# 870   105884.1       52942.1             264710.3
# 472   259802.9      259802.9             519605.9
# 157   613051.8      766314.8            3065259.2
# 378    71639.1       42983.5             143278.2
# ..         ...           ...                  ...
# 84    807353.6     1009192.0            4036767.9
# 141  6544121.3     1963236.4           65441212.7
# 185   529410.8       88235.1            1764702.6
# 302  2058834.0      617650.2           20588340.1
# 311  1411633.8     1764542.3            7058169.2
#
# [1000 rows x 7 columns]

# %% [markdown]
# # 第九題、計算統計量(10% = 4% + 3% + 3%)
# #### 請以「資料集ESG_NumericData」計算：
# 1. 所有欄位個別的平均數、標準差
# 2. EnergyConsumption的中位數
# 3. 所有變數的變異係數矩陣

# %%
ESG_NumericData.mean()
ESG_NumericData.std()
ESG_NumericData['EnergyConsumption_x'].median()
ESG_NumericData.var()
# Out:
# ESG_Overall_x          2.465067e+02
# ESG_Environmental_x    6.765113e+02
# ESG_Social_x           5.500985e+02
# ESG_Governance_x       6.482059e+02
# CO2排放量                 6.749175e+13
# WaterUsage_x           6.316426e+12
# EnergyConsumption_x    6.799581e+15
# dtype: float64

# %% [markdown]
# # 第十題、資料分組(groupby或pivot_table)(10% = 4% + 2% + 2% + 2%)
# #### 請以「資料集Company_ESG」的「ESG成績分組」欄位進行分組，分別計算各組之資料筆數及最大、最小值

# %%
grouped_data = Company_ESG.groupby('ESG成績分組').agg(['count', 'min', 'max'])
print("各ESG成績分組的資料筆數、最大值和最小值:")
grouped_data
# Out:
# 各ESG成績分組的資料筆數、最大值和最小值:
#         Industry                            Region                  Revenue  \
#            count             min        max  count     min      max   count
# ESG成績分組
# 0~60         542  Consumer Goods  Utilities    542  Africa  Oceania     542
# 60~80        379  Consumer Goods  Utilities    379  Africa  Oceania     379
# 80<=          79  Consumer Goods  Utilities     79  Africa  Oceania      79
#
#                          ProfitMargin  ... ESG_Governance_y CarbonEmissions_y  \
#            min       max        count  ...              max             count
# ESG成績分組                                ...
# 0~60     131.4  180810.4          542  ...             96.9               542
# 60~80     35.9  144823.6          379  ...            100.0               379
# 80<=     438.0  134253.3           79  ...            100.0                79
#
#                              WaterUsage_y                      \
#             min          max        count     min         max
# ESG成績分組
# 0~60     4509.9  174104721.4          542  2255.0  52231416.4
# 60~80    2629.6   51147462.4          379  1314.8  15344238.7
# 80<=     6516.3  108229578.1           79  3258.2  32468873.4
#
#         EnergyConsumption_y
#                       count      min           max
# ESG成績分組
# 0~60                    542  11274.8  1.741047e+09
# 60~80                   379   6574.0  5.114746e+08
# 80<=                     79  16290.9  1.082296e+09
#
# [3 rows x 60 columns]

# %% [markdown]
# # 第十一題、請以「資料集Company_ESG」繪製以下統計圖表：(20%)
# 1. ESG_Environmental的直方圖
# 2. 以「Industry」為分組依據，ESG_Overall的盒形圖
# 3. 以第十題中的「ESG成績分組」資料筆數的圓餅圖
# 4. 「Revenue」及「EnergyConsumption」兩變數的散佈圖

# %%
Company_ESG.hist(column='ESG_Environmental_x')
# Out:
# array([[<Axes: title={'center': 'ESG_Environmental_x'}>]], dtype=object)

# %%
Company_ESG_Europe = Company_ESG[Company_ESG['Region'] == 'Europe']

# %%
Company_ESG_Europe
# Out:
#            Industry  Region  Revenue  ProfitMargin  MarketCap  GrowthRate  \
# ID
# 478         Finance  Europe  11483.5           7.9    15330.3         0.5
# 472      Healthcare  Europe   4953.8          14.2     9569.8        14.4
# 157  Consumer Goods  Europe   6055.5          23.8    21083.4        -1.0
# 380          Retail  Europe    741.5          10.8     1094.5        -1.2
# 967      Technology  Europe  31905.9           8.8    70101.1        17.5
# ..              ...     ...      ...           ...        ...         ...
# 565       Utilities  Europe   1772.0           3.2      838.9         4.4
# 43   Transportation  Europe    423.4          -2.4      898.5         7.2
# 278       Utilities  Europe   1968.6          10.4     2004.2        -1.0
# 140   Manufacturing  Europe    959.4          10.3     1113.9        12.6
# 89        Utilities  Europe   1668.6          17.1     2873.0        13.4
#
#      ESG_Overall_x  ESG_Environmental_x  ESG_Social_x  ESG_Governance_x  ...  \
# ID                                                                       ...
# 478           98.0                100.0         100.0              94.0  ...
# 472           95.6                 96.5          99.2              91.3  ...
# 157           95.4                 99.1         100.0              87.2  ...
# 380           94.5                 91.6          94.6              97.3  ...
# 967           94.1                 97.2          91.0              94.1  ...
# ..             ...                  ...           ...               ...  ...
# 565           48.6                 42.2          55.0              48.5  ...
# 43            44.3                 31.1          79.5              22.4  ...
# 278           44.2                 18.9          49.8              63.7  ...
# 140           39.9                 12.2          37.7              69.9  ...
# 89            36.9                 36.4          55.8              18.5  ...
#
#      WaterUsage_x  EnergyConsumption_x  ESG_Overall_y  ESG_Environmental_y  \
# ID
# 478       57417.6             287088.0           98.0                100.0
# 472      259802.9             519605.9           95.6                 96.5
# 157      766314.8            3065259.2           95.4                 99.1
# 380       20718.5              82874.1           94.5                 91.6
# 967      497656.7            1658855.7           94.1                 97.2
# ..            ...                  ...            ...                  ...
# 565      801206.4           12819303.1           48.6                 42.2
# 43        41605.0             832099.3           44.3                 31.1
# 278     1050649.7           16810395.5           44.2                 18.9
# 140      427841.5            5348018.8           39.9                 12.2
# 89       788362.5           12613800.3           36.9                 36.4
#
#      ESG_Social_y  ESG_Governance_y  CarbonEmissions_y  WaterUsage_y  \
# ID
# 478         100.0              94.0           114835.2       57417.6
# 472          99.2              91.3           259802.9      259802.9
# 157         100.0              87.2           613051.8      766314.8
# 380          94.6              97.3            41437.0       20718.5
# 967          91.0              94.1           829427.9      497656.7
# ..            ...               ...                ...           ...
# 565          55.0              48.5          1281930.3      801206.4
# 43           79.5              22.4           249629.8       41605.0
# 278          49.8              63.7          1681039.5     1050649.7
# 140          37.7              69.9           320881.1      427841.5
# 89           55.8              18.5          1261380.0      788362.5
#
#      EnergyConsumption_y  ESG成績分組
# ID
# 478             287088.0     80<=
# 472             519605.9     80<=
# 157            3065259.2     80<=
# 380              82874.1     80<=
# 967            1658855.7     80<=
# ..                   ...      ...
# 565           12819303.1     0~60
# 43              832099.3     0~60
# 278           16810395.5     0~60
# 140            5348018.8     0~60
# 89            12613800.3     0~60
#
# [140 rows x 21 columns]

# %%
Company_ESG_Europe.boxplot(column='ESG_Overall_x', by='Industry')
# Out:
# <Axes: title={'center': 'ESG_Overall_x'}, xlabel='Industry'>

# %%
Company_ESG['ESG成績分組'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
Company_ESG.plot(kind='scatter', x='Revenue', y='EnergyConsumption_x')
# Out:
# <Axes: xlabel='Revenue', ylabel='EnergyConsumption_x'>
